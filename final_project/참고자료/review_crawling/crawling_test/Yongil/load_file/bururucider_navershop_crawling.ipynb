# %% [markdown]
# #### 부르르사이다_네이버쇼핑_크롤링

# %%
import numpy as np
from time import sleep

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# 부르르 제로 사이다 250ml

# %%
driver = webdriver.Chrome('../driver/chromedriver.exe')
url = 'https://search.shopping.naver.com/catalog/27392555522?query=%EB%B6%80%EB%A5%B4%EB%A5%B4%EC%82%AC%EC%9D%B4%EB%8B%A4&NaPm=ct%3Dlc9u9ff4%7Cci%3D8dbe12436b88ed9c427655f31c60c4cea80795fa%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3Dc5c52aa4470eeb6741fd91d1eaaba5fcf072f11d'
driver.get(url)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2780\3565158189.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('../driver/chromedriver.exe')

# %%
driver.find_elements(By.XPATH, f'//*[@id="section_review"]/ul/li[1]/div[2]/div[1]/p')[0].text
# Out:
# '부르르 음료 후기가 좋아서 가격 비교해보고 찾다가 여기서 주문했어요!\n먹어보고 주문한게 아니라 받고 맛 없으면 어쩌나 걱정했는데 생각보다 맛은 먹을 만 했어요\n다른 분 후기에선 밀키스 맛 비슷하다고 표현되있어서 그런 맛 인줄 알았는데 제 입 맛에는 일반 사이다 맛에서 단 맛이 덜하게 느껴졌어요\n그렇다고 단 맛이 전혀 안 나는것 아니고 탄산도 적당히 들어있어요.\n요즘같이 더운 날 음료 많이 마시게 되는데 그럼 알게 모르게 설탕도 많이 섭취하게 되잖아요 이럴때 설탕 제로 음료 마시면 마시면서도 확실히 부담이 덜한 것 같아요. 입으로는 땡기지만 몸에서는 설탕을 부담스러워 할 수 있는 시기에 알맞게 잘 구매한 것 같아요. 있어요.\n가볍게 밥 먹을때나 시원하게 샤워 후에 ~ 너무 많아서 언제 다 먹나 싶었는데 이 기세로 마시면 금새 다 먹을 수 있을 것 같아요 제 혼자 서 있지 못 하는 아이들이 있더라구요 제품에 이상이 있는 것 같진 않고 팽창 된 것 같아서 그냥 따로 모아놓고 우선 순위로 마시고 이있네요 ㅋㅋ 일반 탄산의 시럽맛?이 너무 강하고 자극적으로 느껴지셨던 분들은 한번 드셔보시길 추천드릴께요! 먹고 나서 속이 불편했던? 갈증나는 듯한 느낌이 확실히 덜 해요 다 먹을때 쯤에 미리 주문해 놓으려구요 페트병으로도 파는 것 같은데 저는 휴대해야 할 일이 많아서 캔으로 구매 할 예정 입니다. 집에서 드실 분들은 페트 병도 좋을 것 같아요 사이다가 부르르 제로 콜라에도 관심이 가네요ㅎ 디자인은 사이다가 너무 귀여워서 사이다 먼저 주문했는데 콜라도 한번 도전해 봐야겠어요! ^^ 뭐 해썹 인증이나 성분에 딱히 관심은 없었는데 부르르 사이다는 해썹 인증까지 받은 제품이라 하니 성분적인 면에서는 믿고 마셔도 좋을 것 같아요! 그리고 저는 늦게 알았지만 이미 부르르 사이다가 아는 사람들 사이에서는 평이 좋았더라구요? 괜히 평이 좋은게 아니나 다시금 생각하게 됐네요 ㅎㅎ 아 이렇게 칭찬일색인 이유는 원래 제가 탄산을 식사할때 먹으면 한 캔 정도 밖에 안 마시는데 이
# ...

# %%
review_lst = driver.find_elements(By.XPATH, '//*[@id="section_review"]/ul/li')
len(review_lst)
# Out:
# 20

# %%
lst = []
for i in np.arange(2,13):
    for idx in range(len(review_lst)):
        lst.append(driver.find_elements(By.XPATH, f'//*[@id="section_review"]/ul/li[{idx+1}]/div[2]/div[1]/p')[0].text)
        
    driver.find_element(By.XPATH , f'//*[@id="section_review"]/div[3]/a[{i}]').click()
    sleep(3)    


for page in range(10):
    for i in np.arange(3,13):
        for idx in range(len(review_lst)):
            lst.append(driver.find_elements(By.XPATH, f'//*[@id="section_review"]/ul/li[{idx+1}]/div[2]/div[1]/p')[0].text)

        driver.find_element(By.XPATH ,  f'//*[@id="section_review"]/div[3]/a[{i}]').click()
        sleep(3)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# Input In [6], in <cell line: 10>()
#      11 for i in np.arange(3,13):
#      12     for idx in range(len(review_lst)):
# ---> 13         lst.append(driver.find_elements(By.XPATH, f'//*[@id="section_review"]/ul/li[{idx+1}]/div[2]/div[1]/p')[0].text)
#      15     driver.find_element(By.XPATH ,  f'//*[@id="section_review"]/div[3]/a[{i}]').click()
#      16     sleep(3)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:892, in WebDriver.find_elements(self, by, value)
#     888     value = '[name="%s"]' % value
#     890 # Return empty list if driver returns null
#     891 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 892 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# ...

# %%
lst
# Out:
# ['부르르 음료 후기가 좋아서 가격 비교해보고 찾다가 여기서 주문했어요!\n먹어보고 주문한게 아니라 받고 맛 없으면 어쩌나 걱정했는데 생각보다 맛은 먹을 만 했어요\n다른 분 후기에선 밀키스 맛 비슷하다고 표현되있어서 그런 맛 인줄 알았는데 제 입 맛에는 일반 사이다 맛에서 단 맛이 덜하게 느껴졌어요\n그렇다고 단 맛이 전혀 안 나는것 아니고 탄산도 적당히 들어있어요.\n요즘같이 더운 날 음료 많이 마시게 되는데 그럼 알게 모르게 설탕도 많이 섭취하게 되잖아요 이럴때 설탕 제로 음료 마시면 마시면서도 확실히 부담이 덜한 것 같아요. 입으로는 땡기지만 몸에서는 설탕을 부담스러워 할 수 있는 시기에 알맞게 잘 구매한 것 같아요. 있어요.\n가볍게 밥 먹을때나 시원하게 샤워 후에 ~ 너무 많아서 언제 다 먹나 싶었는데 이 기세로 마시면 금새 다 먹을 수 있을 것 같아요 제 혼자 서 있지 못 하는 아이들이 있더라구요 제품에 이상이 있는 것 같진 않고 팽창 된 것 같아서 그냥 따로 모아놓고 우선 순위로 마시고 이있네요 ㅋㅋ 일반 탄산의 시럽맛?이 너무 강하고 자극적으로 느껴지셨던 분들은 한번 드셔보시길 추천드릴께요! 먹고 나서 속이 불편했던? 갈증나는 듯한 느낌이 확실히 덜 해요 다 먹을때 쯤에 미리 주문해 놓으려구요 페트병으로도 파는 것 같은데 저는 휴대해야 할 일이 많아서 캔으로 구매 할 예정 입니다. 집에서 드실 분들은 페트 병도 좋을 것 같아요 사이다가 부르르 제로 콜라에도 관심이 가네요ㅎ 디자인은 사이다가 너무 귀여워서 사이다 먼저 주문했는데 콜라도 한번 도전해 봐야겠어요! ^^ 뭐 해썹 인증이나 성분에 딱히 관심은 없었는데 부르르 사이다는 해썹 인증까지 받은 제품이라 하니 성분적인 면에서는 믿고 마셔도 좋을 것 같아요! 그리고 저는 늦게 알았지만 이미 부르르 사이다가 아는 사람들 사이에서는 평이 좋았더라구요? 괜히 평이 좋은게 아니나 다시금 생각하게 됐네요 ㅎㅎ 아 이렇게 칭찬일색인 이유는 원래 제가 탄산을 식사할때 먹으면 한 캔 정도 밖에 안 마시는데 
# ...

# %%
len(lst)
# Out:
# 1820

# %%
# to dataframe
tmp1 = pd.DataFrame({'review' : lst})
tmp1.head()
# Out:
#                                               review
# 0  부르르 음료 후기가 좋아서 가격 비교해보고 찾다가 여기서 주문했어요!\n먹어보고 주...
# 1  탄산음료 1도 안마시는 제가 리뷰를 다 쓰네요\n그것도 음용 후 리뷰를요 ㅎ\n탄산...
# 2  사이다를 너무 좋아하는 저희 부부, 칼로리를 걱정하던 차에 무설탕, 무색소, 무보존...
# 3  초정탄산수와 천연사이다의 10년 넘은 팬입니다~몇 박스째 먹는지 모르겠어요. 입안이...
# 4  콜라는 치아를 녹인다는 정보를 알고 난뒤부터 사이다로 바꿔 먹기 시작했어요(탄산은 ...

# %%
tmp1.to_excel('./bururucider_navershop_crawling.xlsx' , index = False)

# %%
# //*[@id="REVIEW"]/div/div[3]/div[2]/ul/li[1]/div/div/div/div[1]/div/div[1]/div[2]/div/span
# //*[@id="REVIEW"]/div/div[3]/div[2]/ul/li[2]/div/div/div/div[1]/div/div/div[2]/div/span
#//*[@id="364839505"]/div/div[1]/div[2]/p
#//*[@id="364839505"]/div/div[1]/div[2]/p

# %%
//*[@id="tap_moving_2"]/a

# %%
driver.find_elements(By.XPATH, f'//*[@id="tap_moving_2"]/a')[0].click()
driver.find_elements(By.XPATH, f'//*[@id="364839505"]/div/div[1]/div[2]/p')[0].text
# Out:
# '저렴하게 잘 산듯합니다 잘 쓰겠습니다'

# %%
for i in range(1 , 10) :
    data = driver.find_element(By.XPATH, f'//*[@id="REVIEW"]/div/div[3]/div[2]/ul/li[{i}]/div/div/div/div[1]/div/div[1]/div[2]/div/span').text
    if data == '재구매' :
        print(driver.find_element(By.XPATH, f'//*[@id="REVIEW"]/div/div[3]/div[2]/ul/li[{i}]/div/div/div/div[1]/div/div[1]/div[2]/div/span[2]').text)
    else :
        print(driver.find_element(By.XPATH, f'//*[@id="REVIEW"]/div/div[3]/div[2]/ul/li[{i}]/div/div/div/div[1]/div/div[1]/div[2]/div/span').text)
# Out:
# 늘 쓰던 제품인데 펑크린 중에 이게 젤 좋아용!!ㅔ
# 효과 정말 좋습니다
# 대충   막히기 전에  콸콸부어주어   잘  내려가고있습니다
# 화장실 청소도 하고 부엌 씽크하수구도 한번씩 뿌려 놓으면 깔끔 해집니다
# 주기적으로 구매해서 사용하고 있습니다.
# 배송 빠르고 좋아요!
# 안전하게 잘 받았습니다.
# 한달사용기
# 빠른배송 감사드립니다

# %%
## //*[@id="review"]/section/div[2]/div[15]
from time import sleep, time


for click in range(10) :
    for i in range(5 , 15) :
        print(driver.find_elements(By.XPATH, f'//*[@id="review"]/section/div[2]/div[{i}]/article/div/p')[0].text)
        print(i)
        print()
    driver.find_elements(By.XPATH, f'//*[@id="review"]/section/div[2]/div[15]/button[2]')[0].click()
    # need break time
    sleep(0.5)
# Out:
# 딸내미가 아파서 보양식으로 급하게 주문해서 먹기 좋아요
# 5
#
# 여러번 사용할수 있어 좋아요, 향이 진하지 않아서 아이랑 잘먹었습니다
# 6
#
# 삼계탕 잘 끓여먹었습니다
# 7
#
# 기름도 잡아주고 좋아요~
# 8
#
# 삼계탕할때 한팩 넣으면 국물향이 달라져요
# 9
#
# 쏘쏘 합니다. 4번째 주문
# 10
#
# 삼계탕 잘 끓여먹었습니다
# 11
#
# 간편해서 좋아요 강추
# 12
#
# 삼계탕 재료 편하고 좋아요
# 13
#
# 편하게 해먹으로 샀어요
# 14
#
# 삼계탕에 넣어 먹으면 맛있어요.
# 5
#
# 좋아요 편해요 굿입니다
# 6
#
# 3개나 들어있네요 근데 진하지 않아요
# 7
#
# 간편하게 삼계탕 할때 딱 좋아요!!
# 8
#
# 국물이 찐하고 맛있네요. 그리고 간편해서 좋고요.
# 9
#
# 잘받았습니당ㅎㅎ좋아요
# 10
#
# 삼계탕 필수품이쥬~
# 11
#
# 닭이랑 이거 하나만 넣어서 끓이면 이름처럼 아주 간편해요
# 12
#
# 삼계탕 재료 팩으로 되어있어 괜찮아요~
# 13
#
# 백숙할때써요 맛좋아요
# 14
#
# 개별되어있어 나눠먹기 조아요
# 5
#
# 삼계탕 먹고싶어서 구매해요
# 6
#
# 삼계탕 재료로 늘 구매해요
# 7
#
# 삼계탕할때 넣었더니 잡내도 없고 편하게 잘했어요 ㅎ
# 8
#
# 뭔가 2% 부족한 느낌이었어요 향이 쌔다고 해야하나
# 9
#
# 백숙에 간편히 넣기 좋아요
# 10
#
# 한팩당 양도많고 좋네요
# 11
#
# 이것저것 들어있어 편리하네요
# 12
#
# 아이 삼계탕 해 줄려고 샀어요 좋아요
# 13
#
# 간편하게 삼계탕 먹었네요..
# 14
#
# 백숙 하기 전에 삼계탕 재료 먼저 끓여서 약재가 우러 나오게 하고 다시 끓이면 한약맛이 잘 나요~
# 5
#
# 삼계탕해먹기 편리하네요!!
# 6
#
# 나눠져있어서 좋아요
# 7
#
# 약재냄새 안강하고 좋았어요
# 8
#
# 이것저것 사지 않아도 되어서 편한 것 같아요
# 9
#
# 간편해서 자주이용합니다~~~
# ...

# %%
driver.find_elements(By.XPATH, f'//*[@id="review"]/section/div[2]/div[14]/article/div/p')[0].text
# Out:
# '한팩에 삼계당 재료가 다양하게 들어가 있어서 정말 간편해요.'

# %%
#//*[@id="review"]/section/div[2]/div[15]/button[2]
driver.find_elements(By.XPATH, f'//*[@id="review"]/section/div[2]/div[15]/button[2]')[0].click()

# %%
# //*[@id="review"]/section/div[2]

driver.find_elements(By.XPATH, f'//*[@id="review"]/section/div[2]')[0]
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c2b3e07b18fca78c1256436b754eecc4", element="78dbd746-952b-4276-8825-5eb31be2f052")>

# %%
driver.find_elements(By.CSS_SELECTOR , '.css-benyte e1ln51kt3')

# <div class="css-benyte e1ln51kt3"><span class="css-1gq7k31 e1ln51kt2">공지</span><button class="css-qbpq7v e1ln51kt1">금주의 베스트 후기 안내</button></div>
# Out:
# []

# %%
dong = []
pop = []
num_shop = []

for i in range(1, len(driver.find_elements(By.CSS_SELECTOR, '#tableBody tr'))+1) :
    dong.append(driver.find_elements(By.XPATH, f'//*[@id="tableBody"]/tr[{i}]/td[1]')[0].text)
    pop.append(driver.find_elements(By.XPATH, f'//*[@id="tableBody"]/tr[{i}]/td[3]')[0].text)
    num_shop.append(driver.find_elements(By.XPATH, f'//*[@id="tableBody"]/tr[{i}]/td[7]')[0].text)

print('dong list : ', dong)
print('pop list : ', pop)
print('num_shop : ', num_shop)

# %%
import requests, openpyxl
from bs4 import BeautifulSoup
import re
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.append(['랭킹', '상품명', '판매가격', '상품상세링크'])

url = "https://www.coupang.com/np/search?component=&q=%EC%8B%A0%EC%9D%BC+%EC%84%9C%ED%81%98%EB%A0%88%EC%9D%B4%ED%84%B0&channel=user"
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.66 Safari/537.36"}
res = requests.get(url, headers = headers, verify=False)
res.raise_for_status()
soup = BeautifulSoup(res.text, "lxml")

items = soup.find_all("li", attrs={"class":re.compile("^search-product")})

item_list = []
for index, item in items:
    name = item.find("div", attrs={"class":"name"}).get_text()
    price = item.find("strong", attrs={"class":"price-value"}).get_text()
    rate = item.find("em", attrs={"class":"rating"})
    if rate:
            rate = rate.get_text()
    else:
        continue
        
    review = item.find("span", attrs={"class":"rating-total-count"})
    if review:
            review = review.get_text()
            review = review[1:-1]
    else:
        continue

    link = item.find("a", attrs={"class":"search-product-link"})["href"]

    print(f"제품명 : {name}")
    print(f"가격 : {price}")
    print(f"평점 : {rate}점 ({review}개)")
    print("바로가기 : {}".format("https://www.coupang.com"+link))
    print("-"*30)
    excel_sheet.append([index+1, name, price, rate, "https://www.coupang.com"+link])
excel_file.save('PRODUCT_LIST.xlsx')
excel_file.close()
# Out:
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.coupang.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
